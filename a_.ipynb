# %% [markdown]
# <a href="https://colab.research.google.com/github/sele709/inteligencia-artificial-tarea/blob/main/a_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

grafo = {
    'A': {'B': 1, 'C': 3},
    'B': {'D': 1, 'E': 4},
    'C': {'F': 2},
    'D': {'G': 5},
    'E': {'G': 1},
    'F': {'G': 2},
    'G': {}
}

heuristica = {
    'A': 7,
    'B': 6,
    'C': 4,
    'D': 5,
    'E': 2,
    'F': 1,
    'G': 0
}

def a_estrella(inicio, objetivo):

    cola = []
    heapq.heappush(cola,(0,inicio))

    camino = {}
    costo = {inicio:0}

    while cola:

        actual = heapq.heappop(cola)[1]

        if actual == objetivo:
            break

        for vecino,peso in grafo[actual].items():

            nuevo_costo = costo[actual] + peso

            if vecino not in costo or nuevo_costo < costo[vecino]:

                costo[vecino] = nuevo_costo
                prioridad = nuevo_costo + heuristica[vecino]

                heapq.heappush(cola,(prioridad,vecino))
                camino[vecino] = actual

    ruta = []
    nodo = objetivo

    while nodo != inicio:
        ruta.append(nodo)
        nodo = camino[nodo]

    ruta.append(inicio)
    ruta.reverse()

    return ruta

resultado = a_estrella('A','G')

print("Camino encontrado:")
print(" -> ".join(resultado))
# Out:
# Camino encontrado:
# A -> B -> E -> G
